# %% [markdown]
# ### Exploratory data analysis of TMED dataset, opening the image files

# %%
import pandas as pd
import numpy as np
import os
import random
import PIL.Image as Image
from matplotlib import pyplot as plt
import re

# %%
def LoadImage(file_path):
    im = Image.open(file_path)
    im = np.asarray(im)/255
    return im

# %%
def ShowGrayscaleImage(file_path, title='', ax=None):
    
    im = LoadImage(file_path)
    if ax is None:
        plt.figure()
    plt.axis('off')
    
    plt.imshow(im , cmap=plt.cm.gray, vmin=0, vmax=1) #im is of float, 0-1

    plt.title(title)

# %%
# create a dataframe from the DEV478 split
dataset_root = "/data/TMED/approved_users_only"
folds = [f'TMED2_fold{i}_labeledpart.csv' for i in range(3)]
print(folds)
csv_files = [os.path.join(dataset_root, "DEV479", f) for f in folds]
print(csv_files)
# Out:
# ['TMED2_fold0_labeledpart.csv', 'TMED2_fold1_labeledpart.csv', 'TMED2_fold2_labeledpart.csv']
# ['/data/TMED/approved_users_only/DEV479/TMED2_fold0_labeledpart.csv', '/data/TMED/approved_users_only/DEV479/TMED2_fold1_labeledpart.csv', '/data/TMED/approved_users_only/DEV479/TMED2_fold2_labeledpart.csv']

# %%
# load dataframe for each part
dfs = [pd.read_csv(c) for c in csv_files]
dfs[0]
# Out:
#            query_key view_classifier_split diagnosis_classifier_split  \
# 0       4860s1_0.png                 train                      train
# 1       4860s1_1.png                 train                      train
# 2       4860s1_2.png                 train                      train
# 3       4860s1_3.png                 train                      train
# 4       4860s1_4.png                 train                      train
# ...              ...                   ...                        ...
# 24959  2797s1_28.png                 train                   not_used
# 24960    235s1_0.png                 train                   not_used
# 24961    235s1_1.png                 train                   not_used
# 24962    235s1_2.png                 train                   not_used
# 24963    235s1_3.png                 train                   not_used
#
#       view_label diagnosis_label                            SourceFolder
# 0            A4C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 1            A2C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 2           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 3           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 4           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# ...          ...             ...                                     ...
# 24959        A4C    Not_Provided                view_labeled_set/labeled
# 24960       PLAX    Not_Provided                view_labeled_set/labeled
# 24961        A4C    Not_Provided                view_labeled_set/labeled
# 24962       PLAX    Not_Provided                view_labeled_set/labeled
# 24963        A4C    Not_Provided                view_labeled_set/labeled
#
# [24964 rows x 6 columns]

# %%
def studyinfo_from_query_key(s):
    # Define the regular expression pattern
    pattern = r'(\d+)s(\d+)_(\d+)\.png'
    
    # Use re.match to search for the pattern in the string
    match = re.match(pattern, s)
    
    # If a match is found, extract the groups and return them as a tuple
    if match:
        ID, studyNum, imageNum = match.groups()
        return int(ID), int(studyNum), int(imageNum)
    else:
        return None

# %%
# combine the three splits into a big dataset
df = pd.concat(dfs).reset_index()
df
# Out:
#        index      query_key view_classifier_split diagnosis_classifier_split  \
# 0          0   4860s1_0.png                 train                      train
# 1          1   4860s1_1.png                 train                      train
# 2          2   4860s1_2.png                 train                      train
# 3          3   4860s1_3.png                 train                      train
# 4          4   4860s1_4.png                 train                      train
# ...      ...            ...                   ...                        ...
# 74887  24959  2797s1_28.png                 train                   not_used
# 74888  24960    235s1_0.png                 train                   not_used
# 74889  24961    235s1_1.png                 train                   not_used
# 74890  24962    235s1_2.png                 train                   not_used
# 74891  24963    235s1_3.png                 train                   not_used
#
#       view_label diagnosis_label                            SourceFolder
# 0            A4C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 1            A2C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 2           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 3           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 4           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# ...          ...             ...                                     ...
# 74887        A4C    Not_Provided                view_labeled_set/labeled
# 74888       PLAX    Not_Provided                view_labeled_set/labeled
# 74889        A4C    Not_Provided                view_labeled_set/labeled
# 74890       PLAX    Not_Provided                view_labeled_set/labeled
# 74891        A4C    Not_Provided                view_labeled_set/labeled
#
# [74892 rows x 7 columns]

# %%
# confirm there are no repeating values in the dataset
df['query_key'].value_counts()
# Out:
# 4860s1_0.png     3
# 1970s1_5.png     3
# 2542s1_13.png    3
# 2542s1_12.png    3
# 2542s1_11.png    3
#                 ..
# 5310s1_2.png     3
# 5310s1_1.png     3
# 5310s1_0.png     3
# 29s1_15.png      3
# 235s1_3.png      3
# Name: query_key, Length: 24964, dtype: int64

# %%
# seems like each is used 3 times. check if they are used across different train/test sets
df[df['query_key']=='4860s1_0.png']
# Out:
#        index     query_key view_classifier_split diagnosis_classifier_split  \
# 0          0  4860s1_0.png                 train                      train
# 35323  10359  4860s1_0.png                   val                        val
# 63739  13811  4860s1_0.png                  test                       test
#
#       view_label diagnosis_label                            SourceFolder
# 0            A4C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 35323       PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 63739       PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled

# %%
# makes sense. so we only need to use one of them
df = dfs[0]
df
# Out:
#            query_key view_classifier_split diagnosis_classifier_split  \
# 0       4860s1_0.png                 train                      train
# 1       4860s1_1.png                 train                      train
# 2       4860s1_2.png                 train                      train
# 3       4860s1_3.png                 train                      train
# 4       4860s1_4.png                 train                      train
# ...              ...                   ...                        ...
# 24959  2797s1_28.png                 train                   not_used
# 24960    235s1_0.png                 train                   not_used
# 24961    235s1_1.png                 train                   not_used
# 24962    235s1_2.png                 train                   not_used
# 24963    235s1_3.png                 train                   not_used
#
#       view_label diagnosis_label                            SourceFolder
# 0            A4C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 1            A2C     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 2           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 3           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 4           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# ...          ...             ...                                     ...
# 24959        A4C    Not_Provided                view_labeled_set/labeled
# 24960       PLAX    Not_Provided                view_labeled_set/labeled
# 24961        A4C    Not_Provided                view_labeled_set/labeled
# 24962       PLAX    Not_Provided                view_labeled_set/labeled
# 24963        A4C    Not_Provided                view_labeled_set/labeled
#
# [24964 rows x 6 columns]

# %%
# what type of values do we expect for each field?
def print_df_value_counts(df):
    cols = df.columns
    for c in cols:
        print(df[c].value_counts())
        print("----")
print_df_value_counts(df)
# Out:
# 4860s1_0.png     1
# 1970s1_5.png     1
# 2542s1_13.png    1
# 2542s1_12.png    1
# 2542s1_11.png    1
#                 ..
# 5310s1_2.png     1
# 5310s1_1.png     1
# 5310s1_0.png     1
# 29s1_15.png      1
# 235s1_3.png      1
# Name: query_key, Length: 24964, dtype: int64
# ----
# train    17760
# val       3602
# test      3602
# Name: view_classifier_split, dtype: int64
# ----
# train       10066
# not_used     7694
# val          3602
# test         3602
# Name: diagnosis_classifier_split, dtype: int64
# ----
# PLAX               7372
# A4CorA2CorOther    6861
# A4C                4565
# A2C                3436
# PSAX               2730
# Name: view_label, dtype: int64
# ----
# Not_Provided    7694
# severe_AS       7556
# moderate_AS     5905
# no_AS           1682
# mild_AS         1675
# mildtomod_AS     452
# Name: diagnosis_label, dtype: int64
# ----
# view_and_diagnosis_labeled_set/labeled    17270
# view_labeled_set/labeled                   7694
# Name: SourceFolder, dtype: int64
# ----

# %%
# remove the data that do not have diagnosis labels and redo
df_filtered = df[df['diagnosis_label']!='Not_Provided']
print_df_value_counts(df_filtered)
# Out:
# 4860s1_0.png     1
# 3100s1_31.png    1
# 3100s1_17.png    1
# 3100s1_18.png    1
# 3100s1_19.png    1
#                 ..
# 3670s1_56.png    1
# 3670s1_57.png    1
# 3670s1_58.png    1
# 318s1_0.png      1
# 5897s1_20.png    1
# Name: query_key, Length: 17270, dtype: int64
# ----
# train    10066
# val       3602
# test      3602
# Name: view_classifier_split, dtype: int64
# ----
# train    10066
# val       3602
# test      3602
# Name: diagnosis_classifier_split, dtype: int64
# ----
# A4CorA2CorOther    6861
# PLAX               4808
# A4C                2206
# PSAX               1725
# A2C                1670
# Name: view_label, dtype: int64
# ----
# severe_AS       7556
# moderate_AS     5905
# no_AS           1682
# mild_AS         1675
# mildtomod_AS     452
# Name: diagnosis_label, dtype: int64
# ----
# view_and_diagnosis_labeled_set/labeled    17270
# Name: SourceFolder, dtype: int64
# ----

# %%
# also try removing non-parasternal views
df_parasternal = df_filtered[(df_filtered['view_label'] == 'PLAX') | (df_filtered['view_label'] == 'PSAX')]
#df_parasternal = df_filtered[df_filtered['view_label'] in ['PLAX', 'PSAX']] 
print_df_value_counts(df_parasternal)
# Out:
# 4860s1_2.png    1
# 3400s1_6.png    1
# 3100s1_3.png    1
# 3100s1_2.png    1
# 376s1_6.png     1
#                ..
# 3523s2_4.png    1
# 3523s2_3.png    1
# 3523s2_2.png    1
# 3523s2_1.png    1
# 5897s1_6.png    1
# Name: query_key, Length: 6533, dtype: int64
# ----
# train    3846
# test     1377
# val      1310
# Name: view_classifier_split, dtype: int64
# ----
# train    3846
# test     1377
# val      1310
# Name: diagnosis_classifier_split, dtype: int64
# ----
# PLAX    4808
# PSAX    1725
# Name: view_label, dtype: int64
# ----
# severe_AS       2235
# moderate_AS     1910
# no_AS           1381
# mild_AS          735
# mildtomod_AS     272
# Name: diagnosis_label, dtype: int64
# ----
# view_and_diagnosis_labeled_set/labeled    6533
# Name: SourceFolder, dtype: int64
# ----

# %%
def get_filename(row):
    return os.path.join(dataset_root, row['SourceFolder'], row['query_key'])
df_parasternal['filename'] = df_parasternal.apply(get_filename, axis=1)
df_parasternal
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           query_key view_classifier_split diagnosis_classifier_split  \
# 2      4860s1_2.png                 train                      train
# 3      4860s1_3.png                 train                      train
# 4      4860s1_4.png                 train                      train
# 5      4860s1_5.png                 train                      train
# 6      4860s1_6.png                 train                      train
# ...             ...                   ...                        ...
# 17251  5897s1_2.png                  test                       test
# 17252  5897s1_3.png                  test                       test
# 17253  5897s1_4.png                  test                       test
# 17254  5897s1_5.png                  test                       test
# 17255  5897s1_6.png                  test                       test
#
#       view_label diagnosis_label                            SourceFolder  \
# 2           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 3           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 4           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 5           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# 6           PLAX     moderate_AS  view_and_diagnosis_labeled_set/labeled
# ...          ...             ...                                     ...
# 17251       PLAX       severe_AS  view_and_diagnosis_labeled_set/labeled
# 17252       PLAX       severe_AS  view_and_diagnosis_labeled_set/labeled
# 17253       PLAX       severe_AS  view_and_diagnosis_labeled_set/labeled
# 17254       PSAX       severe_AS  view_and_diagnosis_labeled_set/labeled
# 17255       PLAX       severe_AS  view_and_diagnosis_labeled_set/labeled
#
#                                                 filename
# 2      /data/TMED/approved_users_only/view_and_diagno...
# 3      /data/TMED/approved_users_only/view_and_diagno...
# 4      /data/TMED/approved_users_only/view_and_diagno...
# 5      /data/TMED/approved_users_only/view_and_diagno...
# 6      /data/TMED/approved_users_only/view_and_diagno...
# ...                                                  ...
# 17251  /data/TMED/approved_users_only/view_and_diagno...
# 17252  /data/TMED/approved_users_only/view_and_diagno...
# 17253  /data/TMED/approved_users_only/view_and_diagno...
# 17254  /data/TMED/approved_users_only/view_and_diagno...
# 17255  /data/TMED/approved_users_only/view_and_diagno...
#
# [6533 rows x 7 columns]

# %%
ShowGrayscaleImage(df_parasternal.iloc[0]['filename'])
im = LoadImage(df_parasternal.iloc[0]['filename'])
im.shape
# Out:
# (112, 112)

# %%
im = Image.open(df_parasternal.iloc[5]['filename'])
im = im.convert("RGB")

# %%
import torchvision.transforms as transforms
#tfs = transforms.Compose(
#            [transforms.Resize(size=(self.img_resolution, self.img_resolution)),
#            transforms.ToTensor(), 
#            transforms.Normalize((0.0521,0.0521,0.0521),(0.0104,0.0104,0.0104))
#            ])
tfs = transforms.transforms.ToTensor()
im_tensor = tfs(im)
im1 = im_tensor.numpy()
im2 = transforms.functional.adjust_gamma(im_tensor, gamma=0.5).numpy()

# %%
plt.imshow(np.transpose(im1, (1,2,0)))

# %%
plt.imshow(np.transpose(im2, (1,2,0)))
